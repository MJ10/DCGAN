# %%
import tensorflow as tf
from DCGAN import DCGAN

# %%
sess = tf.InteractiveSession()

# %%
dcgan = DCGAN(sess)

# %%
dcgan.train()
# Out:
# Reading checkpoints...
# Failed to find a checkpoint
# Failed to load checkpoint
# Epoch: [ 0] [   0/ 656] time: 4.2723, d_loss: 2.03893757, g_loss: 1.06331253
# Epoch: [ 0] [   1/ 656] time: 7.5791, d_loss: 1.44347703, g_loss: 0.79079098
# Epoch: [ 0] [   2/ 656] time: 10.7856, d_loss: 1.57802367, g_loss: 0.83481425
# Epoch: [ 0] [   3/ 656] time: 14.1497, d_loss: 1.41454661, g_loss: 0.73678613
# Epoch: [ 0] [   4/ 656] time: 17.6897, d_loss: 1.40448689, g_loss: 0.73262763
# Epoch: [ 0] [   5/ 656] time: 20.7389, d_loss: 1.40822208, g_loss: 0.73405617
# Epoch: [ 0] [   6/ 656] time: 23.7498, d_loss: 1.38986611, g_loss: 0.71777880
# Epoch: [ 0] [   7/ 656] time: 26.7384, d_loss: 1.38211179, g_loss: 0.70702904
# Epoch: [ 0] [   8/ 656] time: 29.7635, d_loss: 1.38359272, g_loss: 0.70501333
# Epoch: [ 0] [   9/ 656] time: 33.2618, d_loss: 1.37442875, g_loss: 0.71298790
# Epoch: [ 0] [  10/ 656] time: 36.6879, d_loss: 1.37676787, g_loss: 0.72065371
# ...
